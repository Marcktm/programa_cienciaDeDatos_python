# %% [markdown]
# # 📘 Clase 1 – ¿Qué es la Ciencia de Datos?
#
# ## 🎯 Objetivos:
# - Conocer qué es la Ciencia de Datos y para qué sirve.
# - Iniciar en Python usando Google Colab.
# - Usar `print()`, comentarios, variables y tipos de datos básicos.

# %% [markdown]
# ## 📊 ¿Qué es la Ciencia de Datos?
#
# La ciencia de datos es una disciplina que combina estadística, programación y conocimiento para analizar datos y encontrar respuestas.
#
# Ejemplos cotidianos:
# - Recomendaciones de YouTube o Spotify
# - Clasificación de fotos
# - Juegos que te dicen cuánto jugaste
# - Valoración de jugadores en el FIFA

# %% [markdown]
# ## 🧪 ¡Empezamos con Python!
#
# ### Mostramos nuestro primer mensaje:

# %%
print("Hola, ciencia de datos!")

# %% [markdown]
# ### Comentarios en Python
# Sirven para dejar notas en el código. No se ejecutan.

# %%
# Este es un comentario
print("Estoy aprendiendo a programar")

# %% [markdown]
# ### Tipos de datos y variables
# Podemos guardar datos en "cajitas" llamadas variables:

# %%
nombre = "Luna"
edad = 12
promedio = 8.5
participa = True

print("Nombre:", nombre)
print("Edad:", edad)
print("Promedio:", promedio)
print("¿Participa?:", participa)

# %% [markdown]
# ## ✅ Desafío 1
# Cambiá los valores por los tuyos:
# - Tu nombre
# - Tu edad
# - Tu materia favorita
#
# Mostralos con `print()`
